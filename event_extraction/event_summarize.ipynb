# %% [markdown]
# # Using SpaCy to extract noun and verb

# %%
import pandas as pd
import spacy
from pathlib import Path

# %%
MAIN_PATH = Path(r"C:\Users\lhi30\Haein\2023\YBIGTA\2023-2\DA\Wiki_People\Share")

# %%
test_df = pd.read_csv(MAIN_PATH / "event_extraction/Winston_Churchill.csv")
test_df
# Out:
#       Unnamed: 0     0                                                  1  \
# 0              0  1911   .mw-parser-output .sidebar{width:22em;float:r...
# 1              1  1922  Apart from two years between 1922 and 1924, he...
# 2              2  1940  Ideologically an adherent to economic liberali...
# 3              3  1904  He was a member of the Liberal Party from 1904...
# 4              4  1895  He joined the British Army in 1895 and saw act...
# ...          ...   ...                                                ...
# 2153        2153  2010                            Seldon, Anthony (2010).
# 2154        2154  1951  Churchill's Indian Summer: The Conservative Go...
# 2155        2155  2021                          Smith, Gary Scott (2021).
# 2156        2156  8028                            ISBN 978-0-8028-7700-0.
# 2157        2157  2010                              Toye, Richard (2010).
#
#                     2    3
# 0             summary  NaN
# ...

# %%
test = test_df.iloc[40, 2]
test
# Out:
# 'His father died in January 1895, a month after Churchill graduated from Sandhurst.'

# %%
import spacy

nlp = spacy.load("en_core_web_trf")

# %%
print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)

# %%
doc = nlp(test)
# for token in doc:
#     if token.pos_ in ["VERB"]:
#         print(token.text)
# for chunk in doc.noun_chunks:
#     print(chunk.text,)
for ent in doc.ents:
    print(ent.text, ent.label_)

print("\n")
for token in doc:
    if token.pos_ in ["PRON","PROPN","PROP", "NOUN", "VERB"]:
        print(token.text,token.dep_)
# Out:
# January 1895 DATE
# a month DATE
# Churchill PERSON
# Sandhurst ORG
#
#
# His poss
# father nsubj
# died ROOT
# January pobj
# month npadvmod
# Churchill nsubj
# graduated advcl
# Sandhurst pobj

# %%
from spacy import displacy
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="15e1e730385d4ed5a8e372b35e06d910-0" class="displacy" width="2325" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">His</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">father</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...
