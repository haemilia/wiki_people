# %%
import json

our_path3 = r'C:\Users\inny9\Documents\GitHub\wiki_people\wiki_crawling\name_list_2_new.json'

with open(our_path3, 'r') as file:
    name_list = json.load(file)

# %%
name_list
# Out:
# ['Winston Churchill',
#  'Martin Luther King ',
#  'Nelson Mandela ',
#  'Mahatma Gandhi',
#  'Franklin D. Roosevelt',
#  'John Paul II',
#  'Theodore Roosevelt',
#  'Adolf Hitler ',
#  'Joseph Stalin',
#  'V.I. Lenin',
#  'Dwight Eisenhower',
#  'Ronald Reagan',
#  'Woodrow Wilson ',
#  'Margaret Thatcher',
#  'Charles de Gaulle',
#  'Jawaharlal Nehru',
#  'John F Kennedy',
#  'Mikhail Gorbachev ',
#  'Hilary Clinton',
#  'Benazir Bhutto',
#  'Desmond Tutu',
#  'Ataturk',
#  'Boris Yeltsin ',
#  'Kofi Annan',
#  'Dalai Lama',
#  'Aung San Suu Kyi',
#  'Lyndon Johnson',
#  'Indira Gandhi',
#  'Eva Peron',
#  'Malcolm X',
#  'Tony Blair',
#  'Mother Teresa',
#  'Eleanor Roosevelt',
#  'Rosa Parks ',
#  'Princess Diana',
#  'Raisa Gorbachev',
#  'Abbe Pierre',
#  'Albert Einstein',
#  'Nikola Tesla',
#  'Marie Curie\xa0',
#  'Alexander Fleming ',
#  'John Logie Baird',
#  'Enrico Fermi',
#  'Stephen Hawking',
#  'Rosalind Franklin',
#  'Tim Berners-Lee',
#  'Pablo Picasso',
# ...

# %%
len(name_list)
# Out:
# 177

# %%
categories = ['Politics', 'Academics', 'Entertainment', 'Sports', 'Fine Arts', 'Business']

# %%
people_occupations = {
 'Winston Churchill': 'Politics',
 'Martin Luther King': 'Politics',
 'Nelson Mandela': 'Politics',
 'Mahatma Gandhi': 'Politics',
 'Franklin D. Roosevelt': 'Politics',
 'John Paul II': 'Politics',
 'Theodore Roosevelt': 'Politics',
 'Adolf Hitler': 'Politics',
 'Joseph Stalin': 'Politics',
 'V.I. Lenin': 'Politics',
 'Dwight Eisenhower': 'Politics',
 'Ronald Reagan': 'Politics',
 'Woodrow Wilson': 'Politics',
 'Margaret Thatcher': 'Politics',
 'Charles de Gaulle': 'Politics',
 'Jawaharlal Nehru': 'Politics',
 'John F Kennedy': 'Politics',
 'Mikhail Gorbachev': 'Politics',
 'Hilary Clinton': 'Politics',
 'Benazir Bhutto': 'Politics',
 'Desmond Tutu': 'Politics',
 'Ataturk': 'Politics',
 'Boris Yeltsin': 'Politics',
 'Kofi Annan': 'Politics',
 'Dalai Lama': 'Politics',
 'Aung San Suu Kyi': 'Politics',
 'Lyndon Johnson': 'Politics',
 'Indira Gandhi': 'Politics',
 'Eva Peron': 'Politics',
 'Malcolm X': 'Politics',
 'Tony Blair': 'Politics',
 'Mother Teresa': 'Politics',
 'Eleanor Roosevelt': 'Politics',
 'Rosa Parks': 'Politics',
 'Princess Diana': 'Politics',
 'Raisa Gorbachev': 'Politics',
 'Abbe Pierre': 'Politics',
 'Albert Einstein': 'Academics',
 'Nikola Tesla': 'Academics',
 'Marie Curie\xa0': 'Academics',
 'Alexander Fleming': 'Academics',
 'John Logie Baird': 'Academics',
 'Enrico Fermi': 'Academics',
 'Stephen Hawking': 'Academics',
 'Rosalind Franklin': 'Academics',
 'Tim Berners-Lee': 'Academics',
 'Pablo Picasso': 'Fine Arts',
 'Salvador Dali': 'Fine Arts',
 'Coco Chanel': 'Fine Arts',
 'David Hockney': 'Fine Arts',
 'Edvard Munch': 'Fine Arts',
 'General Patton': 'Fine Arts',
 'T.E. Lawrence': 'Fine Arts',
 'Douglas Haig': 'Fine Arts',
 'Bernard Montgomery': 'Fine Arts',
 'George Orwell': 'Fine Arts',
 'J.R.R.Tolkien': 'Fine Arts',
 'Oscar Wilde': 'Fine Arts',
 'Ernest Hemingway': 'Fine Arts',
 'John Steinbeck': 'Fine Arts',
 'Anne Frank': 'Fine Arts',
 'J.K.Rowling': 'Fine Arts',
 'J.K.Rowling': 'Fine Arts',
 'Virginia Woolf': 'Fine Arts',
 'Germaine Greer': 'Fine Arts',
 'Beatrix Potter': 'Fine Arts',
 'C.S. Lewis': 'Fine Arts',
 'Wilfred Owens': 'Fine Arts',
 'Gabriela Mistral': 'Fine Arts',
 'John Lennon': 'Entertainment',
 'Elvis Presley': 'Entertainment',
 'Michael Jackson': 'Entertainment',
 'Madonna': 'Entertainment',
 'Elton John': 'Entertainment',
 'Bob Geldof': 'Entertainment',
 'Cliff Richard': 'Entertainment',
 'Paul McCartney': 'Entertainment',
 'George Harrison': 'Entertainment',
 'Elvis Presley': 'Entertainment',
 'Billie Holiday': 'Entertainment',
 'Pele': 'Sports',
 'Jesse Owens': 'Sports',
 'Babe Ruth': 'Sports',
 'Muhammed Ali': 'Sports',
 'Roger Bannister': 'Sports',
 'Carl Lewis': 'Sports',
 'Bobby Moore': 'Sports',
 'Sir Donald Bradman': 'Sports',
 'Eddy Merckx': 'Sports',
 'David Beckham': 'Sports',
 'Diego Maradona': 'Sports',
 'Tegla Laroupe': 'Sports',
 'Michael Jordan': 'Sports',
 'Sachin Tendulkar': 'Sports',
 'Billie Jean King': 'Sports',
 'Aryton Senna': 'Sports',
 'Lewis Hamilton': 'Sports',
 'Bill Gates': 'Business',
 'Richard Branson': 'Business',
 'Al Capone': 'Business',
 'Henry Ford': 'Business',
 'Steve Jobs': 'Business',
 'Audrey Hepburn': 'Entertainment',
 'Michael Caine': 'Entertainment',
 'Richard Burton': 'Entertainment',
 'Marilyn Monroe': 'Entertainment',
 'Sir Charlie Chaplin': 'Entertainment',
 'Alec Guinness': 'Entertainment',
 'Peter Sellers': 'Entertainment',
 'Richard Attenborough': 'Entertainment',
 'Katherine Hepburn': 'Entertainment',
 'Julie Andrews': 'Entertainment',
 'Alfred Hitchcock': 'Entertainment',
 'Walt Disney': 'Entertainment',
 'Michael Moore': 'Entertainment',
 'Oprah Winfrey': 'Entertainment',
 'Jacqueline Kennedy Onassis': 'Entertainment',
 'Neil Armstrong': 'Academics',
 'Lord Baden Powell': 'Politics',
 'Sri Aurobindo': 'Politics',
 'Maharishi Mahesh Yogi': 'Politics',
 'Paramahansa Yogananda': 'Politics',
 'Xi Jinping': 'Politics',
 'Barack Obama': 'Politics',
 'Oprah Winfrey': 'Entertainment',
 'Hillary Clinton': 'Politics',
 'Angela Merkel': 'Politics',
 'Joe Biden': 'Politics',
 'Pope Francis': 'Politics',
 'Jeff Bezos': 'Business',
 'Tim Cook': 'Business',
 'Steve Jobs': 'Business',
 'Christine Lagarde': 'Business',
 'Narendra Modi': 'Politics',
 'Aung San Suu Kyi': 'Politics',
 'Nancy Pelosi': 'Politics',
 'Bill Clinton': 'Politics',
 'George Clooney': 'Politics',
 'Jamie Dimon': 'Business',
 'Recep Tayyip Erdoğan': 'Politics',
 'Bill Gates': 'Business',
 'Hu Jintao': 'Politics',
 'LeBron James': 'Sports',
 'Benjamin Netanyahu': 'Politics',
 'Michelle Obama': 'Politics',
 'Condoleezza Rice': 'Politics',
 'Elizabeth Warren': 'Politics',
 'Janet Yellen': 'Politics',
 'Mark Zuckerberg': 'Business',
 'Taylor Swift': 'Entertainment',
 'Adele': 'Entertainment',
 'Pope Benedict XVI': 'Politics',
 'Beyonce': 'Entertainment',
 'Warren Buffett': 'Business',
 'Catherine, Princess of Wales': 'Entertainment',
 '14th Dalai Lama': 'Politics',
 'Mario Draghi': 'Politics',
 'Kamala Harris': 'Politics',
 'Bob Iger': 'Business',
 'John Kerry': 'Politics',
 'Charles Koch': 'Business',
 'David Koch': 'Business',
 'Luiz Inácio Lula da Silva': 'Politics',
 'Ma Huateng': 'Business',
 'Nelson Mandela': 'Politics',
 'Lionel Messi': 'Sports',
 'Rupert Murdoch': 'Business',
 'Naomi Osaka': 'Sports',
 'Larry Page': 'Business',
 'Brad Pitt': 'Entertainment',
 'Ren Zhengfei': 'Business',
 'Shonda Rhimes': 'Entertainment',
 'John Roberts': 'Politics',
 'Muqtada al-Sadr': 'Politics',
 'Tiger Woods': 'Sports',
 'Malala Yousafzai': 'Politics',
 'John Maynard Keynes': 'Academics'
}

# %%
for i in name_list:
    if i in people_occupations.keys():
        print(f"{i} is here, and their occupation is {people_occupations[i]}")
    else:
        print(f"{i} not here!!!!!!!!!")
# Out:
# Winston Churchill is here, and their occupation is Politics
# Martin Luther King  is here, and their occupation is Politics
# Nelson Mandela  is here, and their occupation is Politics
# Mahatma Gandhi is here, and their occupation is Politics
# Franklin D. Roosevelt is here, and their occupation is Politics
# John Paul II is here, and their occupation is Politics
# Theodore Roosevelt is here, and their occupation is Politics
# Adolf Hitler  is here, and their occupation is Politics
# Joseph Stalin is here, and their occupation is Politics
# V.I. Lenin is here, and their occupation is Politics
# Dwight Eisenhower is here, and their occupation is Politics
# Ronald Reagan is here, and their occupation is Politics
# Woodrow Wilson  is here, and their occupation is Politics
# Margaret Thatcher is here, and their occupation is Politics
# Charles de Gaulle is here, and their occupation is Politics
# Jawaharlal Nehru is here, and their occupation is Politics
# ...

# %%
for k, v in people_occupations.items():
    if v in categories:
            print("good")
    else:
        print(f"{k}!!!!!!!!!!!!!!!!!!! Wrong category")
# Out:
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# ...

# %%
import pandas as pd
import glob
import os

# Path to the directory containing CSV files
directory_path = r'C:\Users\inny9\Desktop\drive-download-20231126T084721Z-001/*.csv'  # Replace 'your_directory_path' with your directory path
output_file = 'merged_file.csv'  # Name of the output file

# Get a list of file paths for all CSV files in the directory
file_list = glob.glob(directory_path)

for file in file_list:
    file_name = os.path.basename(file)  # Extract the file name without the path
    df = pd.read_csv(file)  # Read the CSV into a DataFrame
    df['Name'] = str(file_name)[:-4]
    df.to_csv(file, index=False)  # Save the modified DataFrame back to the CSV file

# %%
# Create an empty DataFrame to store the merged data
merged_data = pd.DataFrame()

# Loop through each file and concatenate data into the merged_data DataFrame
for file in file_list:
    data = pd.read_csv(file)  # Read each CSV file
    merged_data = pd.concat([merged_data, data], ignore_index=True)  # Concatenate data

# Write the merged data to a new CSV file
merged_data.to_csv(output_file, index=False)

df = pd.read_csv(output_file)
df
# Out:
#       year  age                                              event  \
# 0     1937    2  14th Dalai Lama was selected as the tulku of t...
# 1     1935    0  14th Dalai Lama was born on 6 July 1935 to a f...
# 2     1940    5  14th Dalai Lama's formal rule as head of the g...
# 3     1954   19  On 27 September 1954, 14th Dalai Lama was sele...
# 4     1999   64  In 14th Dalai Lama's essay "The Ethic of Compa...
# ...    ...  ...                                                ...
# 1326  1914   51  Henry Ford announced his $5-per-day program on...
# 1327  1901   38  Henry Ford maintained an interest in auto raci...
# 1328  1996  133  , Henry Ford did make quite an impact on auto ...
# 1329  1915   52  Henry Ford had a vacation residence in Fort My...
# 1330  1936   73  In 1936, Henry Ford broke ground for a beautif...
#
#                       category1  \
# 0                       summary
# 1     Early life and background
# 2        Life as the Dalai Lama
# ...

# %%
new_column = df['Name']  # Extracting the new column

# Dropping the 'New_Column' from its current position
df = df.drop(columns=['Name'])

# Inserting the 'New_Column' at index 0
df.insert(loc=0, column='Name', value=new_column)

df
# Out:
#                  Name  year  age  \
# 0     14th Dalai Lama  1937    2
# 1     14th Dalai Lama  1935    0
# 2     14th Dalai Lama  1940    5
# 3     14th Dalai Lama  1954   19
# 4     14th Dalai Lama  1999   64
# ...               ...   ...  ...
# 1326       Henry Ford  1914   51
# 1327       Henry Ford  1901   38
# 1328       Henry Ford  1996  133
# 1329       Henry Ford  1915   52
# 1330       Henry Ford  1936   73
#
#                                                   event  \
# 0     14th Dalai Lama was selected as the tulku of t...
# 1     14th Dalai Lama was born on 6 July 1935 to a f...
# 2     14th Dalai Lama's formal rule as head of the g...
# 3     On 27 September 1954, 14th Dalai Lama was sele...
# 4     In 14th Dalai Lama's essay "The Ethic of Compa...
# ...                                                 ...
# 1326  Henry Ford announced his $5-per-day program on...
# 1327  Henry Ford maintained an interest in auto raci...
# ...

# %%
df.to_csv(r'C:\Users\inny9\Desktop\drive-download-20231126T084721Z-001\merged_person.csv', index=False)

# %%
# Create a new column based on matching keys from 'Column_0' to the dictionary keys
df['Occupation'] = df['Name'].map(people_occupations)
df = df.drop('Occupations', axis=1)
df
# Out:
#                  Name  year  age  \
# 0     14th Dalai Lama  1937    2
# 1     14th Dalai Lama  1935    0
# 2     14th Dalai Lama  1940    5
# 3     14th Dalai Lama  1954   19
# 4     14th Dalai Lama  1999   64
# ...               ...   ...  ...
# 1326       Henry Ford  1914   51
# 1327       Henry Ford  1901   38
# 1328       Henry Ford  1996  133
# 1329       Henry Ford  1915   52
# 1330       Henry Ford  1936   73
#
#                                                   event  \
# 0     14th Dalai Lama was selected as the tulku of t...
# 1     14th Dalai Lama was born on 6 July 1935 to a f...
# 2     14th Dalai Lama's formal rule as head of the g...
# 3     On 27 September 1954, 14th Dalai Lama was sele...
# 4     In 14th Dalai Lama's essay "The Ethic of Compa...
# ...                                                 ...
# 1326  Henry Ford announced his $5-per-day program on...
# 1327  Henry Ford maintained an interest in auto raci...
# ...

# %%
df
# Out:
#                  Name  year  age  \
# 0     14th Dalai Lama  1937    2
# 1     14th Dalai Lama  1935    0
# 2     14th Dalai Lama  1940    5
# 3     14th Dalai Lama  1954   19
# 4     14th Dalai Lama  1999   64
# ...               ...   ...  ...
# 1326       Henry Ford  1914   51
# 1327       Henry Ford  1901   38
# 1328       Henry Ford  1996  133
# 1329       Henry Ford  1915   52
# 1330       Henry Ford  1936   73
#
#                                                   event  \
# 0     14th Dalai Lama was selected as the tulku of t...
# 1     14th Dalai Lama was born on 6 July 1935 to a f...
# 2     14th Dalai Lama's formal rule as head of the g...
# 3     On 27 September 1954, 14th Dalai Lama was sele...
# 4     In 14th Dalai Lama's essay "The Ethic of Compa...
# ...                                                 ...
# 1326  Henry Ford announced his $5-per-day program on...
# 1327  Henry Ford maintained an interest in auto raci...
# ...

# %%
#check if the occupations are all mapped correctly without omissions
nan_count = df['Occupation'].isna().sum()

# Display the count of NaN values in 'Column_A'
print(f"Number of NaN values in 'Column_A': {nan_count}")

rows_with_nan = df[df['Occupation'].isnull()]
print("Rows with NaN in 'Column_A':")
#rows_with_nan
# Out:
# Number of NaN values in 'Column_A': 0
# Rows with NaN in 'Column_A':

# %%
cd '/Users/jinsungyang/Documents/YBIGTA/으라차차 위키키킼/Shared/data/labeled_final_df'
# Out:
# /Users/jinsungyang/Documents/YBIGTA/으라차차 위키키킼/Shared/data/labeled_final_df

# %%
import numpy as np
import pandas as pd

# %%
import os
persons_csv = os.listdir()

# %%
temp_data = pd.read_csv('/Users/jinsungyang/Documents/YBIGTA/으라차차 위키키킼/Shared/data/labeled_final_df/Alfred Hitchcock_labeled.csv')

# %%
merged_df = pd.DataFrame()
error = []
    
for i in persons_csv:
    try:
        print(i)
        temp_data = pd.read_csv(f'/Users/jinsungyang/Documents/YBIGTA/으라차차 위키키킼/Shared/data/labeled_final_df/{i}', encoding='ISO-8859-1')
        merged_df = pd.concat([merged_df,temp_data], ignore_index=True)
    except:
        error.append(i)
        print("error:", i)
# Out:
# Alfred Hitchcock_labeled.csv
# Alexander Fleming_labeled.csv
# David Beckham_labeled.csv
# Edvard Munch_labeled.csv
# David Hockney_labeled.csv
# John Paul II_labeled.csv
# Babe Ruth_labeled.csv
# Shonda Rhimes_labeled.csv
# John F Kennedy_labeled.csv
# Neil Armstrong_labeled.csv
# Lyndon Johnson_labeled.csv
# Larry Page_labeled.csv
# Roger Bannister_labeled.csv
# John Maynard Keynes_labeled.csv
# Muhammed Ali_labeled.csv
# Ren Zhengfei_labeled.csv
# 14th Dalai Lama_labeled.csv
# Condoleezza Rice_labeled.csv
# Cliff Richard_labeled.csv
# Richard Burton_labeled.csv
# Julie Andrews_labeled.csv
# Adele_labeled.csv
# Joe Biden_labeled.csv
# Jesse Owens_labeled.csv
# Michael Caine_labeled.csv
# Marilyn Monroe_labeled.csv
# .DS_Store
# error: .DS_Store
# Benazir Bhutto_labeled.csv
# Joseph Stalin_labeled.csv
# Pope Benedict XVI_labeled.csv
# Anne Frank_labeled.csv
# Recep Tayyip Erdogan_labeled.csv
# T.E. Lawrence_labeled.csv
# Oprah Winfrey_labeled.csv
# Rupert Murdoch_labeled.csv
# ...

# %%
error
# Out:
# ['.DS_Store']

# %%
merged_df
# Out:
#       year  age                                              event  \
# 0     1955   56  Known as the "Master of Suspense", Alfred Hitc...
# 1     1935   36  Alfred Hitchcock's thrillers The 39 Steps (193...
# 2     1944   45  Alfred Hitchcock also received the Academy Awa...
# 3     1955   56  Alfred Hitchcock became an American citizen in...
# 4     2021  122  As of 2021[update], nine of Alfred Hitchcock's...
# ...    ...  ...                                                ...
# 3435  2021   39  Catherine, Princess of Wales was also chosen a...
# 3436  2022   40  In December 2022, Catherine, Princess of Wales...
# 3437  2005   23  In 2005 after Catherine, Princess of Wales was...
# 3438  2006   24  In April 2006, Catherine, Princess of Wales's ...
# 3439  2007   25  Media attention increased around the time of C...
#
#                    category1 category2                          Name  \
# 0                    summary       NaN              Alfred Hitchcock
# ...

# %%
merged_df = merged_df[['Name','year', 'age', 'event', 'category1', 'category2', 
       'Career/Personal Life']]

# %%
merged_df['Occupation'] = merged_df['Name'].map(people_occupations)
# Out:
# /var/folders/sp/7yb9y0mj4rg9tw1qnb4js7x40000gn/T/ipykernel_60432/2903211301.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['Occupation'] = merged_df['Name'].map(people_occupations)

# %%
merged_df = merged_df[['Name','year', 'age', 'event', 'category1', 'category2', 
       'Occupation','Career/Personal Life']]

# %%
merged_df.to_csv('/Users/jinsungyang/Documents/YBIGTA/으라차차 위키키킼/Shared/inyoung_final_df_labeled.csv',index=False)
